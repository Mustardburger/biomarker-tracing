# %%
import scanpy as sc
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Explore the data

# %% [markdown]
# ## Check the genes with high specificity in the brain

# %%
df = pd.read_csv("/sc/arion/projects/DiseaseGeneCell/Huang_lab_project/BioResNetwork/Phuc/projects/Alzheimer/human_atlas/results/cell_type_specificity/markers_wilcox_tissue-cell_max-1000.tsv", sep="\t")

# %%
# Number of clusters
n_clusters = len(df["cluster"].unique())

# Merge gene names
gene_names = pd.read_csv("/sc/arion/projects/DiseaseGeneCell/Huang_lab_project/BioResNetwork/Phuc/datasets/Alzheimer/CSF_proteomics_AD_onset/gene_id_symbol_df.tsv", sep="\t").rename(columns={"gene_ids": "gene", "gene_symbols": "gene_name"})
final_df = df.merge(gene_names, how="left", on="gene")

# Extract tissue and cell types
final_df["tissue"] = final_df["cluster"].apply(lambda x: x.split(":")[0])
final_df["cell_type"] = final_df["cluster"].apply(lambda x: x.split(":")[1])
n_tissues = len(final_df["tissue"].unique())
n_cells = len(final_df["cell_type"].unique())

# %%
# Overlap genes in Nature paper with atlas
disease = "Alzheimer's dementia"
prot_df = pd.read_csv("/sc/arion/projects/DiseaseGeneCell/Huang_lab_project/BioResNetwork/Phuc/projects/Alzheimer/nature_proteomics_papers/blood_protein_assessment_of_leading_incident_diseases_and_mortality_in_the_UK_Biobank/supp_table_4_tmp.tsv", sep="\t", index_col="Unnamed: 0")
prot_df["gene_name"] = prot_df["Predictor"].apply(lambda x: x.split(".")[0])
prot_df["ci_outside_1"] = ((prot_df["LCI"] > 1.0) | (prot_df["UCI"] < 1.0))

prot_specific = prot_df[prot_df["Outcome"] == disease]

# %%
# Merge the two
prot_atlas = prot_specific.merge(final_df, how="left", on="gene_name").dropna()

# %%
# Count the number of tissues for each cell type (top genes are mostly immune)
prot_atlas[["tissue", "cell_type"]].groupby("cell_type")["tissue"].nunique().to_frame().sort_values(by="tissue", ascending=False).head(5)
# Out:
#                   tissue
# cell_type
# macrophage            27
# T cell                20
# fibroblast            18
# mature NK T cell      16
# endothelial cell      16

# %%
# Calculate max avg log2fc for each gene
max_avg_log2fc = prot_atlas.loc[prot_atlas.groupby('gene_name')['avg_log2FC'].idxmax()]

# %%
brain_regions = ["dorsolateral prefrontal cortex", "middle temporal gyrus", "angular gyrus"]
max_avg_log2fc_sig_genes = max_avg_log2fc[(max_avg_log2fc["ci_outside_1"]) & (max_avg_log2fc["tissue"].isin(brain_regions))]
max_avg_log2fc_sig_genes[["gene_name", "tissue", "cell_type", "avg_log2FC", "P.Value"]].sort_values(by="avg_log2FC", ascending=False).head(40)
# Out:
#       gene_name                          tissue  \
# 34599    ACVRL1  dorsolateral prefrontal cortex
# 42019      BST2           middle temporal gyrus
# 33813     EPHA2  dorsolateral prefrontal cortex
# 28331     SUSD2  dorsolateral prefrontal cortex
# 3          GFAP  dorsolateral prefrontal cortex
# 35265   PIK3AP1           middle temporal gyrus
# 38294      IL18           middle temporal gyrus
# 13174     CNDP1           middle temporal gyrus
# 37526      GPC5                   angular gyrus
# 18917      AREG           middle temporal gyrus
# 19657     SMOC1           middle temporal gyrus
# 21334      VWA1           middle temporal gyrus
# 18923      KLK4  dorsolateral prefrontal cortex
# 18486     ERBB3  dorsolateral prefrontal cortex
# 37087       PXN  dorsolateral prefrontal cortex
# 31806     HSPB6                   angular gyrus
# 1948       BCAN           middle temporal gyrus
# 28309    PLXDC1  dorsolateral prefrontal cortex
# 31810       ADA           middle temporal gyrus
# 27057   COL18A1  dorsolateral prefrontal cortex
# 22849    SPINK4                   angular gyrus
# 30538     CNTN5           middle temporal gyrus
# 10138    IGFBP2           middle temporal gyrus
# 40933     PILRA                   angular gyrus
# 34561     PRDX6           middle temporal gyrus
# 11565     LRRN1  dorsolateral prefrontal cortex
# 21070     CALB1                   angular gyrus
# 16849      CES3  dorsolateral prefrontal cortex
# 20075    GALNT2           middle temporal gyrus
# 2644      WNT9A           middle temporal gyrus
# 37538        F7  dorsolateral prefrontal cortex
# 8754       LDLR                   angular gyrus
# 20454      ROR1           middle temporal gyrus
# 39275     PTPRM  dorsolateral prefrontal cortex
# 33495     MEGF9           middle temporal gyrus
# 37112     GPA33  dorsolateral prefrontal cortex
# 4552      PDGFC  dorsolateral prefrontal cortex
# 15403     IL17D  dorsolateral prefrontal cortex
# 17645     CDHR5                   angular gyrus
# 11164     MEP1B                   angular gyrus
#
#                                                cell_type  avg_log2FC  \
# 34599                   cerebral cortex endothelial cell   10.143899
# 42019                   cerebral cortex endothelial cell    9.828073
# 33813                       vascular leptomeningeal cell    8.540105
# 28331                       vascular leptomeningeal cell    8.523788
# 3                       astrocyte of the cerebral cortex    7.277635
# 35265                                    microglial cell    7.130358
# 38294                                    microglial cell    6.136988
# 13174                                    oligodendrocyte    5.968187
# 37526                   astrocyte of the cerebral cortex    5.933930
# 18917                 vip GABAergic cortical interneuron    5.779522
# 19657                     oligodendrocyte precursor cell    5.742054
# 21334                                    oligodendrocyte    5.648278
# 18923      near-projecting glutamatergic cortical neuron    5.577203
# 18486                                    oligodendrocyte    5.563045
# 37087                   cerebral cortex endothelial cell    5.517688
# 31806                 vip GABAergic cortical interneuron    5.490866
# 1948                      oligodendrocyte precursor cell    5.412416
# 28309                       vascular leptomeningeal cell    4.976682
# 31810                                    oligodendrocyte    4.970983
# 27057                   cerebral cortex endothelial cell    4.812077
# 22849  L5 extratelencephalic projecting glutamatergic...    4.594449
# 30538    chandelier pvalb GABAergic cortical interneuron    4.456393
# 10138                       vascular leptomeningeal cell    4.369484
# 40933                                    microglial cell    4.293910
# 34561                   astrocyte of the cerebral cortex    4.166101
# 11565                     oligodendrocyte precursor cell    4.027204
# 21070                 sst GABAergic cortical interneuron    3.913395
# 16849      near-projecting glutamatergic cortical neuron    3.888522
# 20075                                    microglial cell    3.777023
# 2644                   L6b glutamatergic cortical neuron    3.608806
# 37538    chandelier pvalb GABAergic cortical interneuron    3.600505
# 8754                    cerebral cortex endothelial cell    3.409816
# 20454               pvalb GABAergic cortical interneuron    3.387821
# 39275                   cerebral cortex endothelial cell    2.976301
# 33495                                    oligodendrocyte    2.959273
# 37112      near-projecting glutamatergic cortical neuron    2.944476
# 4552                      oligodendrocyte precursor cell    2.837795
# 15403                   astrocyte of the cerebral cortex    2.837422
# 17645  L5 extratelencephalic projecting glutamatergic...    2.826369
# 11164      near-projecting glutamatergic cortical neuron    2.665515
#
#             P.Value
# 34599  2.320000e-02
# 42019  3.810000e-02
# 33813  2.270000e-02
# 28331  1.670000e-02
# 3      2.830000e-53
# 35265  2.400000e-02
# 38294  3.010000e-02
# 13174  2.650000e-03
# 37526  2.780000e-02
# 18917  5.050000e-03
# 19657  5.610000e-03
# 21334  7.510000e-03
# 18923  5.220000e-03
# 18486  4.900000e-03
# 37087  2.750000e-02
# 31806  2.020000e-02
# 1948   6.400000e-08
# 28309  1.650000e-02
# 31810  2.070000e-02
# 27057  1.430000e-02
# 22849  9.410000e-03
# 30538  1.750000e-02
# 10138  9.030000e-04
# 40933  3.490000e-02
# 34561  2.310000e-02
# 11565  1.310000e-03
# 21070  7.210000e-03
# 16849  3.620000e-03
# 20075  5.680000e-03
# 2644   1.100000e-05
# 37538  2.860000e-02
# 8754   6.420000e-04
# 20454  6.040000e-03
# 39275  3.180000e-02
# 33495  2.140000e-02
# 37112  2.780000e-02
# 4552   1.120000e-04
# 15403  3.200000e-03
# 17645  4.420000e-03
# 11164  1.290000e-03

# %%
# Individual gene inspection
final_df[final_df["gene_name"] == "SPINK4"].sort_values("avg_log2FC", ascending=False)[["gene_name", "tissue", "cell_type", "avg_log2FC"]].head(20)
# Out:
#         gene_name         tissue  \
# 3923085    SPINK4  angular gyrus
#
#                                                  cell_type  avg_log2FC
# 3923085  L5 extratelencephalic projecting glutamatergic...    4.594449

# %% [markdown]
# ## Check the genes based on cell types only

# %%
df = pd.read_csv("/sc/arion/projects/DiseaseGeneCell/Huang_lab_project/BioResNetwork/Phuc/projects/Alzheimer/human_atlas/results/cell_type_specificity/markers_wilcox_cell_max-1000_downsamp.tsv", sep="\t")

# %%
# Number of clusters
n_clusters = len(df["cluster"].unique())

# Merge gene names
gene_names = pd.read_csv("/sc/arion/projects/DiseaseGeneCell/Huang_lab_project/BioResNetwork/Phuc/datasets/Alzheimer/CSF_proteomics_AD_onset/gene_id_symbol_df.tsv", sep="\t").rename(columns={"gene_ids": "gene", "gene_symbols": "gene_name"})
final_df = df.merge(gene_names, how="left", on="gene").rename(columns={"cluster": "cell_type"})

# Extract cell types
n_cells = len(final_df["cell_type"].unique())

# %%
# Overlap genes in Nature paper with atlas
disease = "Alzheimer's dementia"
prot_df = pd.read_csv("/sc/arion/projects/DiseaseGeneCell/Huang_lab_project/BioResNetwork/Phuc/projects/Alzheimer/nature_proteomics_papers/blood_protein_assessment_of_leading_incident_diseases_and_mortality_in_the_UK_Biobank/supp_table_4_tmp.tsv", sep="\t", index_col="Unnamed: 0")
prot_df["gene_name"] = prot_df["Predictor"].apply(lambda x: x.split(".")[0])
prot_df["ci_outside_1"] = ((prot_df["LCI"] > 1.0) | (prot_df["UCI"] < 1.0))

prot_specific = prot_df[prot_df["Outcome"] == disease]

# Merge the two
prot_atlas = prot_specific.merge(final_df, how="left", on="gene_name").dropna()

# %%
# Calculate max avg log2fc for each gene
max_avg_log2fc = prot_atlas.loc[prot_atlas.groupby('gene_name')['avg_log2FC'].idxmax()]

# Extract only significant genes
max_avg_log2fc_sig_genes = max_avg_log2fc[(max_avg_log2fc["ci_outside_1"])]

# %%
max_avg_log2fc_sig_genes[["gene_name", "cell_type", "avg_log2FC", "P.Value", "HR"]].sort_values(by="HR", ascending=False).head(40)
# Out:
#      gene_name                                 cell_type  avg_log2FC  \
# 54        GFAP          astrocyte of the cerebral cortex    9.243537
# 166       NEFL                              Mueller cell    3.873071
# 266      GDF15                   bladder urothelial cell    6.378637
# 305       BRK1                                  platelet    1.990856
# 927      WNT9A               small intestine goblet cell    5.694206
# 1009      SPP1                    kidney epithelial cell    4.630120
# 1114   CEACAM5                      paneth cell of colon    6.725437
# 1778     ACTA2    vascular associated smooth muscle cell    6.152659
# 1341     LTBP2                     mesenchymal stem cell    5.478004
# 4158      MMP3                              stromal cell    7.766400
# 2140      TFF3               small intestine goblet cell    9.086248
# 3490     WFDC2                      duct epithelial cell    6.202470
# 2539    IL1RL1                                 mast cell    5.935372
# 2398    CLEC5A                            dendritic cell    7.182730
# 2747      NPPB                       cardiac muscle cell    9.105887
# 2868    SPINK1                    pancreatic acinar cell    8.221959
# 3144     SPON1          astrocyte of the cerebral cortex    5.108137
# 3326    CHI3L1  luminal epithelial cell of mammary gland    5.613686
# 3386    IGFBP2                        smooth muscle cell    4.801298
# 5276     EDA2R                      fibroblast of breast    4.427206
# 4117       PVR                      intestinal tuft cell    3.560532
# 3926     REG3A               small intestine goblet cell    8.591503
# 4040      NCS1      pvalb GABAergic cortical interneuron    2.020804
# 3676       DCN                          adventitial cell    5.417912
# 4312      TGFA            oligodendrocyte precursor cell    3.581749
# 5496     IL17D          astrocyte of the cerebral cortex    3.554047
# 4823     GFRA1                     mesenchymal stem cell    4.784013
# 5700    HAVCR1                           microglial cell    4.201958
# 4409      PSG1      lamp5 GABAergic cortical interneuron    3.033276
# 5535     PLAUR                   corneal epithelial cell    4.305370
# 5305      C1QA                                macrophage    6.350001
# 5227     CD276                      fibroblast of breast    2.413478
# 6446     KITLG      lamp5 GABAergic cortical interneuron    2.657395
# 6837      KLK4       luminal cell of prostate epithelium   10.569135
# 7145     SMOC1            oligodendrocyte precursor cell    6.319587
# 6721      AREG                                 mast cell    3.802057
# 6160   TINAGL1    vascular associated smooth muscle cell    4.498025
# 6461      IL19                            secretory cell    5.973590
# 4937      PTX3                     mesenchymal stem cell    4.437205
# 5775      ESM1                  cardiac endothelial cell    5.247868
#
#            P.Value    HR
# 54    2.830000e-53  2.25
# 166   9.000000e-26  1.77
# 266   1.690000e-10  1.42
# 305   1.640000e-08  1.31
# 927   1.100000e-05  1.25
# 1009  1.470000e-05  1.23
# 1114  1.730000e-05  1.23
# 1778  1.720000e-04  1.22
# 1341  1.060000e-04  1.22
# 4158  1.580000e-03  1.21
# 2140  2.120000e-04  1.21
# 3490  9.190000e-04  1.20
# 2539  3.970000e-04  1.20
# 2398  3.550000e-04  1.19
# 2747  4.530000e-04  1.18
# 2868  6.080000e-04  1.18
# 3144  8.070000e-04  1.18
# 3326  8.790000e-04  1.18
# 3386  9.030000e-04  1.18
# 5276  2.920000e-03  1.18
# 4117  1.570000e-03  1.17
# 3926  1.440000e-03  1.17
# 4040  1.500000e-03  1.17
# 3676  1.230000e-03  1.17
# 4312  1.630000e-03  1.17
# 5496  3.200000e-03  1.16
# 4823  2.680000e-03  1.16
# 5700  3.340000e-03  1.16
# 4409  2.070000e-03  1.16
# 5535  3.220000e-03  1.16
# 5305  2.950000e-03  1.16
# 5227  2.880000e-03  1.16
# 6446  4.760000e-03  1.15
# 6837  5.220000e-03  1.15
# 7145  5.610000e-03  1.15
# 6721  5.050000e-03  1.15
# 6160  3.720000e-03  1.15
# 6461  4.850000e-03  1.15
# 4937  2.800000e-03  1.15
# 5775  3.440000e-03  1.15

# %% [markdown]
# ## Compare these genes with Human Protein Atlas

# %%
protein_atlas_path = "/sc/arion/projects/DiseaseGeneCell/Huang_lab_project/BioResNetwork/Phuc/projects/Alzheimer/human_protein_atlas"
gene_types = pd.read_csv(f"{protein_atlas_path}/gene_types.tsv", sep="\t")

# %% [markdown]
# # Explore the data for COPD

# %% [markdown]
# ## Some data visualization

# %%
df = pd.read_csv("/sc/arion/projects/DiseaseGeneCell/Huang_lab_project/BioResNetwork/Phuc/projects/Alzheimer/human_atlas/results/cell_type_specificity/markers_wilcox_cell_max-1000_downsamp.tsv", sep="\t")

# %%
# Number of clusters
n_clusters = len(df["cluster"].unique())

# Merge gene names
gene_names = pd.read_csv("/sc/arion/projects/DiseaseGeneCell/Huang_lab_project/BioResNetwork/Phuc/datasets/Alzheimer/CSF_proteomics_AD_onset/gene_id_symbol_df.tsv", sep="\t").rename(columns={"gene_ids": "gene", "gene_symbols": "gene_name"})
final_df = df.merge(gene_names, how="left", on="gene").rename(columns={"cluster": "cell_type"})

# Extract cell types
n_cells = len(final_df["cell_type"].unique())

# %%
# Overlap genes in Nature paper with atlas
disease = "COPD"
prot_df = pd.read_csv("/sc/arion/projects/DiseaseGeneCell/Huang_lab_project/BioResNetwork/Phuc/projects/Alzheimer/nature_proteomics_papers/blood_protein_assessment_of_leading_incident_diseases_and_mortality_in_the_UK_Biobank/supp_table_4_tmp.tsv", sep="\t", index_col="Unnamed: 0")

# With COPD, use author's original threshold
prot_df["gene_name"] = prot_df["Predictor"].apply(lambda x: x.split(".")[0])
#prot_df["ci_outside_1"] = ((prot_df["LCI"] > 1.0) | (prot_df["UCI"] < 1.0))

prot_specific = prot_df[prot_df["Outcome"] == disease]

# Merge the two
prot_atlas = prot_specific.merge(final_df, how="left", on="gene_name").dropna()

# Calculate max avg log2fc for each gene
max_avg_log2fc = prot_atlas.loc[prot_atlas.groupby('gene_name')['avg_log2FC'].idxmax()]

# Extract only significant genes
thres = 3.1e-6
max_avg_log2fc["significant"] = max_avg_log2fc["P.Value"].apply(lambda x: True if x <= thres else False)
max_avg_log2fc_sig_genes = max_avg_log2fc[max_avg_log2fc["significant"]]

# %%
max_avg_log2fc_sig_genes[["gene_name", "cell_type", "avg_log2FC", "P.Value", "HR"]].sort_values(by="HR", ascending=False).head(10)
# Out:
#      gene_name                                 cell_type  avg_log2FC  \
# 78      CXCL17                   respiratory goblet cell    5.573281
# 125      WFDC2                      duct epithelial cell    6.202470
# 320      GDF15                   bladder urothelial cell    6.378637
# 397      LAMP3                        type II pneumocyte    8.811970
# 459      PLAUR                   corneal epithelial cell    4.305370
# 592  TNFRSF10B         endothelial cell of vascular tree    3.010317
# 635       ALPP                         type I pneumocyte    8.089865
# 766      MMP12                      fibroblast of breast    6.990190
# 668       PIGR                                enterocyte    5.530908
# 936      PRSS8  luminal epithelial cell of mammary gland    4.785446
#
#            P.Value    HR
# 78    0.000000e+00  2.61
# 125  6.510000e-307  2.58
# 320  1.700000e-265  2.44
# 397  1.620000e-246  2.29
# 459  1.730000e-244  2.22
# 592  5.960000e-217  2.19
# 635  5.080000e-216  2.14
# 766  4.200000e-186  2.07
# 668  1.830000e-196  2.03
# 936  1.760000e-152  1.92

# %%
# Count number of genes in each cell type
max_avg_log2fc_sig_genes["cell_type"].value_counts().to_frame().head(10)
# Out:
#                                       count
# cell_type
# neutrophil                               44
# macrophage                               23
# microglial cell                          18
# hepatocyte                               18
# corneal epithelial cell                  16
# CD1c-positive myeloid dendritic cell     15
# oligodendrocyte                          15
# oligodendrocyte precursor cell           13
# vip GABAergic cortical interneuron       12
# cardiac endothelial cell                 12

# %%
max_avg_log2fc_sig_genes[max_avg_log2fc_sig_genes["cell_type"] == "oligodendrocyte"]["gene_name"]
# Out:
# 54395     ALCAM
# 17672     APLP1
# 57371       APP
# 19976     EDIL3
# 45477     ENPP2
# 33930     FGFR2
# 19855     GPR37
# 19050     IGSF8
# 56416      LHPP
# 48111    MEGF10
# 12657     NCAM1
# 54861     NCAM2
# 45679     NFASC
# 49531     SORT1
# 56775    SPOCK1
# Name: gene_name, dtype: object

# %%
# Make a heatmap of log2 of genes
thres = 3.1e-6
prot_atlas_sub = prot_atlas[prot_atlas["P.Value"] <= thres]
prot_atlas_sub = prot_atlas_sub[["gene_name", "cell_type", "avg_log2FC"]]
prot_atlas_sub = pd.pivot_table(prot_atlas_sub, values="avg_log2FC", index="gene_name", columns="cell_type").fillna(0.0)

cmap = sns.diverging_palette(150, 10, s=85, l=55, center="light", as_cmap=True)
sns.set(font_scale=0.7)
plt.figure()
cg = sns.clustermap(prot_atlas_sub, center=0.0, cmap=cmap, figsize=(20, 40), xticklabels=True)
cg.ax_row_dendrogram.set_visible(False)
cg.ax_col_dendrogram.set_visible(False)
cg.cax.set_visible(False)
plt.show()
# Out:
# /sc/arion/projects/DiseaseGeneCell/Huang_lab_project/BioResNetwork/Phuc/conda_env/test-env/envs/scanpy-env/lib/python3.11/site-packages/seaborn/matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)
# /sc/arion/projects/DiseaseGeneCell/Huang_lab_project/BioResNetwork/Phuc/conda_env/test-env/envs/scanpy-env/lib/python3.11/site-packages/seaborn/matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)

# %% [markdown]
# ## Run some correlation analysis

# %%
# An example correlation between HR and avg_log2FC
cell_type = "type I pneumocyte"
lung_cell_ex = max_avg_log2fc[max_avg_log2fc["cell_type"] == cell_type]

plt.figure()
sns.scatterplot(data=lung_cell_ex, x="avg_log2FC", y="HR", hue="significant")
plt.show()
